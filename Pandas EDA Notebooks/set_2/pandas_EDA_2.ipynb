# %%
import pandas as pd

df = pd.read_csv(r"starting_data.csv")

print(df.head(10))
# Out:
#   CustomerID              Name  Age  SignupDate          Location  \
# 0   de78cf38       Amber Reese   56  2025-01-19     Gutierrezport
# 1   0169afb5   Ashley Chandler   69  2025-07-13      Dorothymouth
# 2   c50316e8    Nichole Davies   46  2024-03-06        Port David
# 3   87310bf8     Dakota Nelson   32  2024-12-12       Camachoside
# 4   64d622bc      Haley Hansen   60  2025-03-01       North Sarah
# 5   4dcf3c86  Lisa Proctor DDS   25  2025-04-09     South Michael
# 6   1bb75e35     Curtis Benton   38  2024-06-17       Jessicaport
# 7   c10433d8      Charles Hess   56  2025-02-06         New Julie
# 8   25e31d15     Barbara Brady   36  2024-07-26        Nobleshire
# 9   b85ed570    Matthew Garcia   40  2025-05-02  Port Tamarahaven
#
#                            Email  TotalSpent  NumOrders  IsSubscribed
# 0             andrew58@gmail.com     4829.88         23         False
# 1          ytrujillo@barajas.net     4051.57         24          True
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    50 non-null     object
#  1   Name          50 non-null     object
#  2   Age           50 non-null     int64
#  3   SignupDate    50 non-null     object
#  4   Location      50 non-null     object
#  5   Email         50 non-null     object
#  6   TotalSpent    50 non-null     float64
#  7   NumOrders     50 non-null     int64
#  8   IsSubscribed  50 non-null     bool
# dtypes: bool(1), float64(1), int64(2), object(5)
# memory usage: 3.3+ KB
# None

# %%
df["Location"].nunique()
# Out:
# 50

# %%
df["IsSubscribed"].value_counts()
# Out:
# IsSubscribed
# True     28
# False    22
# Name: count, dtype: int64

# %%
df_subscribed = df[df["IsSubscribed"] == True]

# %%
df_subscribed.shape
# Out:
# (28, 9)

# %%
df.loc[(df["TotalSpent"] > 1000) & (df["NumOrders"] > 5), ["Name", "TotalSpent", "NumOrders"]].sort_values(by=["TotalSpent", "NumOrders"], ascending=[False, False])
# Out:
#                     Name  TotalSpent  NumOrders
# 16       Stephanie Adams     4849.44         23
# 0            Amber Reese     4829.88         23
# 18        Robert Johnson     4700.52          7
# 21     Tiffany Chavez MD     4613.28         15
# 19          Steven Lucas     4479.40          9
# 46        Megan Anderson     4322.36         12
# 39       Kimberly Hughes     4086.53         22
# 1        Ashley Chandler     4051.57         24
# 33         Julie Nielsen     4020.88         15
# 17         Jessica Davis     3886.91         14
# 36            Amy Rogers     3872.61         13
# 42          Kari Sanchez     3867.79         13
# 41         Yvonne Fuller     3658.59         10
# 4           Haley Hansen     3436.95         12
# 11           Peter Smith     3329.49         15
# 47    Shannon Cunningham     3135.33         20
# 20           Brittany Le     3009.60         15
# 31           Tanya Wyatt     2736.35          7
# 5       Lisa Proctor DDS     2228.75          8
# ...

# %%
df[df["IsSubscribed"]]

# something is wrong here, there weren't 49 subscribed customers in the starting dataframe
# Out:
#    CustomerID               Name  Age  SignupDate           Location  \
# 1    0169afb5    Ashley Chandler   69  2025-07-13       Dorothymouth
# 2    c50316e8     Nichole Davies   46  2024-03-06         Port David
# 4    64d622bc       Haley Hansen   60  2025-03-01        North Sarah
# 5    4dcf3c86   Lisa Proctor DDS   25  2025-04-09      South Michael
# 6    1bb75e35      Curtis Benton   38  2024-06-17        Jessicaport
# 7    c10433d8       Charles Hess   56  2025-02-06          New Julie
# 9    b85ed570     Matthew Garcia   40  2025-05-02   Port Tamarahaven
# 11   40a1dac8        Peter Smith   28  2024-10-28          Lake Leah
# 12   eff9d814      Kristen Roman   41  2025-04-26          Garciaton
# 13   faeb241e    Miranda Brennan   53  2024-12-09   South Sandrafurt
# 14   cfcb0e59       Sarah Watson   57  2023-11-18        Zacharyfurt
# 17   6b3e257c      Jessica Davis   39  2025-04-29           Leeburgh
# 18   d5a3728d     Robert Johnson   19  2023-09-13       Jeremiahbury
# ...
